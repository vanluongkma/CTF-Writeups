# %%
from pwn import *
import re

f = remote("03.cr.yp.toc.tf", 13377, level='debug')

f.recvline()
f.recvline()
f.recvline()
f.recvline()

f0_match = re.search(r'f\(0\) = (\d+)', f.recvline().decode())
f0 = int(f0_match.group(1))
print(f"f(0) = {f0}")
fx_match = re.search(r'f\((\d+)\) = (\d+)', f.recvline().decode())
x = int(fx_match.group(1))
fx = int(fx_match.group(2))
print(f"f({x}) = {fx}")

def calculate_f_x(x, f0, fx, y):
    k = (fx - f0) // x
    return y * k + f0

f.recvline()
fx_match = re.search(r'f\((\d+)\):', f.recvline().decode())
y = int(fx_match.group(1))
print(x)

num1 = calculate_f_x(x,f0,fx,y)
print(num1)
f.sendline(str(num1).encode())
f.recvline()
for i in range(10000):
    fx_match = re.search(r'f\((\d+)\):', f.recvline().decode())
    y = int(fx_match.group(1))
    print(x)

    num1 = calculate_f_x(x,f0,fx,y)
    print(num1)
    f.sendline(str(num1).encode())
    f.recvline()
# Out:
# [x] Opening connection to 03.cr.yp.toc.tf on port 13377
# [x] Opening connection to 03.cr.yp.toc.tf on port 13377: Trying 91.107.243.125
# [+] Opening connection to 03.cr.yp.toc.tf on port 13377: Done
# [DEBUG] Received 0x33a bytes:
#     00000000  e2 94 8f e2  94 81 e2 94  81 e2 94 81  e2 94 81 e2  │····│····│····│····│
#     00000010  94 81 e2 94  81 e2 94 81  e2 94 81 e2  94 81 e2 94  │····│····│····│····│
#     00000020  81 e2 94 81  e2 94 81 e2  94 81 e2 94  81 e2 94 81  │····│····│····│····│
#     00000030  e2 94 81 e2  94 81 e2 94  81 e2 94 81  e2 94 81 e2  │····│····│····│····│
#     00000040  94 81 e2 94  81 e2 94 81  e2 94 81 e2  94 81 e2 94  │····│····│····│····│
#     00000050  81 e2 94 81  e2 94 81 e2  94 81 e2 94  81 e2 94 81  │····│····│····│····│
#     00000060  e2 94 81 e2  94 81 e2 94  81 e2 94 81  e2 94 81 e2  │····│····│····│····│
#     00000070  94 81 e2 94  81 e2 94 81  e2 94 81 e2  94 81 e2 94  │····│····│····│····│
#     00000080  81 e2 94 81  e2 94 81 e2  94 81 e2 94  81 e2 94 81  │····│····│····│····│
#     00000090  e2 94 81 e2  94 81 e2 94  81 e2 94 81  e2 94 81 e2  │····│····│····│····│
#     000000a0  94 81 e2 94  81 e2 94 81  e2 94 81 e2  94 81 e2 94  │····│····│····│····│
#     000000b0  81 e2 94 81  e2 94 81 e2  94 81 e2 94  81 e2 94 81  │····│····│····│····│
#     000000c0  e2 94 81 e2  94 81 e2 94  81 e2 94 81  e2 94 81 e2  │····│····│····│····│
#     000000d0  94 93 0a e2  94 83 20 2e  3a 3a 20 20  20 53 6f 75  │····│·· .│::  │ Sou│
#     000000e0  66 69 61 20  69 73 20 61  20 72 61 6e  64 6f 6d 20  │fia │is a│ ran│dom │
#     000000f0  6f 72 61 63  6c 65 2c 20  79 6f 75 72  20 6d 69 73  │orac│le, │your│ mis│
#     00000100  73 69 6f 6e  20 69 73 20  74 6f 20 62  72 65 61 6b  │sion│ is │to b│reak│
#     00000110  20 69 74 20  20 20 3a 3a  2e 20 e2 94  83 0a e2 94  │ it │  ::│. ··│····│
#     00000120  83 20 57 65  20 6b 6e 6f  77 20 74 68  61 74 20 66  │· We│ kno│w th│at f│
#     00000130  3a 20 5a 20  e2 86 92 20  5a 20 61 6e  64 20 66 6f  │: Z │··· │Z an│d fo│
#     00000140  72 20 61 6c  6c 20 69 6e  74 65 67 65  72 73 20 60  │r al│l in│tege│rs `│
#     00000150  78 27 20 61  6e 64 20 60  79 27 20 77  65 20 68 61  │x' a│nd `│y' w│e ha│
#     00000160  76 65 3a 20  20 20 20 e2  94 83 0a e2  94 83 20 20  │ve: │   ·│····│··  │
#     00000170  20 20 20 66  28 74 20 2a  20 78 29 20  2b 20 74 20  │   f│(t *│ x) │+ t │
#     00000180  2a 20 66 28  79 29 20 3d  20 66 28 66  28 78 20 2b  │* f(│y) =│ f(f│(x +│
#     00000190  20 79 29 29  20 66 6f 72  20 63 6f 6e  73 74 61 6e  │ y))│ for│ con│stan│
#     000001a0  74 20 69 6e  74 65 67 65  72 20 60 74  27 2e 20 20  │t in│tege│r `t│'.  │
#     000001b0  20 20 e2 94  83 0a e2 94  83 20 41 6c  73 6f 2c 20  │  ··│····│· Al│so, │
#     000001c0  66 28 30 29  20 3d 20 31  32 39 30 37  30 34 32 38  │f(0)│ = 1│2907│0428│
#     000001d0  35 31 35 37  33 38 37 31  39 32 38 37  31 34 31 36  │5157│3871│9287│1416│
#     000001e0  31 38 34 32  39 38 39 37  32 30 36 38  33 38 2c 20  │1842│9897│2068│38, │
#     000001f0  20 20 20 20  20 20 20 20  20 20 20 20  20 e2 94 83  │    │    │    │ ···│
#     00000200  0a e2 94 83  20 61 6e 64  20 20 20 66  28 34 35 29  │····│ and│   f│(45)│
#     00000210  20 3d 20 35  34 39 38 34  37 30 31 38  34 33 30 39  │ = 5│4984│7018│4309│
#     00000220  35 36 39 33  31 36 33 35  35 34 32 35  31 38 36 38  │5693│1635│5425│1868│
#     00000230  34 38 34 32  33 35 37 31  38 38 33 20  20 20 20 20  │4842│3571│883 │    │
#     00000240  20 20 20 20  20 20 20 20  e2 94 83 0a  e2 94 97 e2  │    │    │····│····│
#     00000250  94 81 e2 94  81 e2 94 81  e2 94 81 e2  94 81 e2 94  │····│····│····│····│
#     00000260  81 e2 94 81  e2 94 81 e2  94 81 e2 94  81 e2 94 81  │····│····│····│····│
#     00000270  e2 94 81 e2  94 81 e2 94  81 e2 94 81  e2 94 81 e2  │····│····│····│····│
#     00000280  94 81 e2 94  81 e2 94 81  e2 94 81 e2  94 81 e2 94  │····│····│····│····│
#     00000290  81 e2 94 81  e2 94 81 e2  94 81 e2 94  81 e2 94 81  │····│····│····│····│
#     000002a0  e2 94 81 e2  94 81 e2 94  81 e2 94 81  e2 94 81 e2  │····│····│····│····│
#     000002b0  94 81 e2 94  81 e2 94 81  e2 94 81 e2  94 81 e2 94  │····│····│····│····│
#     000002c0  81 e2 94 81  e2 94 81 e2  94 81 e2 94  81 e2 94 81  │····│····│····│····│
#     000002d0  e2 94 81 e2  94 81 e2 94  81 e2 94 81  e2 94 81 e2  │····│····│····│····│
#     000002e0  94 81 e2 94  81 e2 94 81  e2 94 81 e2  94 81 e2 94  │····│····│····│····│
#     000002f0  81 e2 94 81  e2 94 81 e2  94 81 e2 94  81 e2 94 81  │····│····│····│····│
#     00000300  e2 94 81 e2  94 81 e2 94  81 e2 94 81  e2 94 81 e2  │····│····│····│····│
#     00000310  94 81 e2 94  81 e2 94 81  e2 94 81 e2  94 9b 0a e2  │····│····│····│····│
#     00000320  94 83 20 50  6c 65 61 73  65 20 73 65  6e 64 20 74  │·· P│leas│e se│nd t│
#     00000330  68 65 20 66  28 32 33 29  3a 0a                     │he f│(23)│:·│
#     0000033a
# f(0) = 129070428515738719287141618429897206838
# f(45) = 5498470184309569316355425186848423571883
# 45
# 2873430303699252135566486553399366237861
# [DEBUG] Sent 0x29 bytes:
#     b'2873430303699252135566486553399366237861\n'
# [DEBUG] Received 0x3d bytes:
#     00000000  e2 94 83 20  47 6f 6f 64  20 6a 6f 62  2c 20 74 72  │··· │Good│ job│, tr│
#     00000010  79 20 74 68  65 20 6e 65  78 74 20 73  74 65 70 20  │y th│e ne│xt s│tep │
#     00000020  32 0a e2 94  83 20 50 6c  65 61 73 65  20 73 65 6e  │2···│· Pl│ease│ sen│
#     00000030  64 20 74 68  65 20 66 28  34 30 29 3a  0a           │d th│e f(│40):│·│
#     0000003d
# 45
# 4901870211443588138903393679246365086878
# [DEBUG] Sent 0x29 bytes:
#     b'4901870211443588138903393679246365086878\n'
# [DEBUG] Received 0x3c bytes:
#     00000000  e2 94 83 20  47 6f 6f 64  20 6a 6f 62  2c 20 74 72  │··· │Good│ job│, tr│
#     00000010  79 20 74 68  65 20 6e 65  78 74 20 73  74 65 70 20  │y th│e ne│xt s│tep │
#     00000020  33 0a e2 94  83 20 50 6c  65 61 73 65  20 73 65 6e  │3···│· Pl│ease│ sen│
#     00000030  64 20 74 68  65 20 66 28  32 29 3a 0a               │d th│e f(│2):·│
#     0000003c
# 45
# 367710417662131190267954221470720600840
# [DEBUG] Sent 0x28 bytes:
#     b'367710417662131190267954221470720600840\n'
# [DEBUG] Received 0x3e bytes:
#     00000000  e2 94 83 20  47 6f 6f 64  20 6a 6f 62  2c 20 74 72  │··· │Good│ job│, tr│
#     00000010  79 20 74 68  65 20 6e 65  78 74 20 73  74 65 70 20  │y th│e ne│xt s│tep │
#     00000020  34 0a e2 94  83 20 50 6c  65 61 73 65  20 73 65 6e  │4···│· Pl│ease│ sen│
#     00000030  64 20 74 68  65 20 66 28  32 35 33 29  3a 0a        │d th│e f(│253)│:·│
#     0000003e
# 45
# 30317029055534386298359935903094056548091
# [DEBUG] Sent 0x2a bytes:
#     b'30317029055534386298359935903094056548091\n'
# [DEBUG] Received 0x3e bytes:
#     00000000  e2 94 83 20  47 6f 6f 64  20 6a 6f 62  2c 20 74 72  │··· │Good│ job│, tr│
#     00000010  79 20 74 68  65 20 6e 65  78 74 20 73  74 65 70 20  │y th│e ne│xt s│tep │
#     00000020  35 0a e2 94  83 20 50 6c  65 61 73 65  20 73 65 6e  │5···│· Pl│ease│ sen│
#     00000030  64 20 74 68  65 20 66 28  31 36 38 29  3a 0a        │d th│e f(│168)│:·│
#     0000003e
# 45
# 20174829516812706281675400273859062303006
# [DEBUG] Sent 0x2a bytes:
#     b'20174829516812706281675400273859062303006\n'
# [DEBUG] Received 0x3e bytes:
#     00000000  e2 94 83 20  47 6f 6f 64  20 6a 6f 62  2c 20 74 72  │··· │Good│ job│, tr│
#     00000010  79 20 74 68  65 20 6e 65  78 74 20 73  74 65 70 20  │y th│e ne│xt s│tep │
#     00000020  36 0a e2 94  83 20 50 6c  65 61 73 65  20 73 65 6e  │6···│· Pl│ease│ sen│
#     00000030  64 20 74 68  65 20 66 28  38 32 35 29  3a 0a        │d th│e f(│825)│:·│
#     0000003e
# 45
# 98568065951402632998872340372769547232663
# [DEBUG] Sent 0x2a bytes:
#     b'98568065951402632998872340372769547232663\n'
# [DEBUG] Received 0x3e bytes:
#     00000000  e2 94 83 20  47 6f 6f 64  20 6a 6f 62  2c 20 74 72  │··· │Good│ job│, tr│
#     00000010  79 20 74 68  65 20 6e 65  78 74 20 73  74 65 70 20  │y th│e ne│xt s│tep │
#     00000020  37 0a e2 94  83 20 50 6c  65 61 73 65  20 73 65 6e  │7···│· Pl│ease│ sen│
#     00000030  64 20 74 68  65 20 66 28  38 36 34 29  3a 0a        │d th│e f(│864)│:·│
#     0000003e
# 45
# 103221545739757286182998186132065603415702
# [DEBUG] Sent 0x2b bytes:
#     b'103221545739757286182998186132065603415702\n'
# [DEBUG] Received 0x3f bytes:
#     00000000  e2 94 83 20  47 6f 6f 64  20 6a 6f 62  2c 20 74 72  │··· │Good│ job│, tr│
#     00000010  79 20 74 68  65 20 6e 65  78 74 20 73  74 65 70 20  │y th│e ne│xt s│tep │
#     00000020  38 0a e2 94  83 20 50 6c  65 61 73 65  20 73 65 6e  │8···│· Pl│ease│ sen│
#     00000030  64 20 74 68  65 20 66 28  33 38 32 35  29 3a 0a     │d th│e f(│3825│):·│
#     0000003f
# 45
# 456528049670991339470091244934004638235663
# [DEBUG] Sent 0x2b bytes:
#     b'456528049670991339470091244934004638235663\n'
# [DEBUG] Received 0x3e bytes:
#     00000000  e2 94 83 20  47 6f 6f 64  20 6a 6f 62  2c 20 74 72  │··· │Good│ job│, tr│
#     00000010  79 20 74 68  65 20 6e 65  78 74 20 73  74 65 70 20  │y th│e ne│xt s│tep │
#     00000020  39 0a e2 94  83 20 50 6c  65 61 73 65  20 73 65 6e  │9···│· Pl│ease│ sen│
#     00000030  64 20 74 68  65 20 66 28  33 36 31 29  3a 0a        │d th│e f(│361)│:·│
#     0000003e
# 45
# 43203588469439579731323816467298519824199
# [DEBUG] Sent 0x2a bytes:
#     b'43203588469439579731323816467298519824199\n'
# [DEBUG] Received 0x41 bytes:
#     00000000  e2 94 83 20  47 6f 6f 64  20 6a 6f 62  2c 20 74 72  │··· │Good│ job│, tr│
#     00000010  79 20 74 68  65 20 6e 65  78 74 20 73  74 65 70 20  │y th│e ne│xt s│tep │
#     00000020  31 30 0a e2  94 83 20 50  6c 65 61 73  65 20 73 65  │10··│·· P│leas│e se│
#     00000030  6e 64 20 74  68 65 20 66  28 31 34 38  33 32 29 3a  │nd t│he f│(148│32):│
#     00000040  0a                                                  │·│
#     00000041
# 45
# 1769883229938162303512993405769176187125670
# [DEBUG] Sent 0x2c bytes:
#     b'1769883229938162303512993405769176187125670\n'
# [DEBUG] Received 0x41 bytes:
#     00000000  e2 94 83 20  47 6f 6f 64  20 6a 6f 62  2c 20 74 72  │··· │Good│ job│, tr│
#     00000010  79 20 74 68  65 20 6e 65  78 74 20 73  74 65 70 20  │y th│e ne│xt s│tep │
#     00000020  31 31 0a e2  94 83 20 50  6c 65 61 73  65 20 73 65  │11··│·· P│leas│e se│
#     00000030  6e 64 20 74  68 65 20 66  28 31 38 35  39 35 29 3a  │nd t│he f│(185│95):│
#     00000040  0a                                                  │·│
#     00000041
# 45
# 2218884369517099737663392318390485402940433
# [DEBUG] Sent 0x2c bytes:
#     b'2218884369517099737663392318390485402940433\n'
# [DEBUG] Received 0x41 bytes:
#     00000000  e2 94 83 20  47 6f 6f 64  20 6a 6f 62  2c 20 74 72  │··· │Good│ job│, tr│
#     00000010  79 20 74 68  65 20 6e 65  78 74 20 73  74 65 70 20  │y th│e ne│xt s│tep │
#     00000020  31 32 0a e2  94 83 20 50  6c 65 61 73  65 20 73 65  │12··│·· P│leas│e se│
#     00000030  6e 64 20 74  68 65 20 66  28 35 30 30  30 38 29 3a  │nd t│he f│(500│08):│
#     00000040  0a                                                  │·│
#     00000041
# 45
# 5967083359044913083123525468051178040832846
# [DEBUG] Sent 0x2c bytes:
#     b'5967083359044913083123525468051178040832846\n'
# [DEBUG] Received 0x42 bytes:
#     00000000  e2 94 83 20  47 6f 6f 64  20 6a 6f 62  2c 20 74 72  │··· │Good│ job│, tr│
#     00000010  79 20 74 68  65 20 6e 65  78 74 20 73  74 65 70 20  │y th│e ne│xt s│tep │
#     00000020  31 33 0a e2  94 83 20 50  6c 65 61 73  65 20 73 65  │13··│·· P│leas│e se│
#     00000030  6e 64 20 74  68 65 20 66  28 31 31 33  39 30 38 29  │nd t│he f│(113│908)│
#     00000040  3a 0a                                               │:·│
#     00000042
# 45
# 13591631012272152530960488135205485479196746
# [DEBUG] Sent 0x2d bytes:
#     b'13591631012272152530960488135205485479196746\n'
# [DEBUG] Received 0x42 bytes:
#     00000000  e2 94 83 20  47 6f 6f 64  20 6a 6f 62  2c 20 74 72  │··· │Good│ job│, tr│
#     00000010  79 20 74 68  65 20 6e 65  78 74 20 73  74 65 70 20  │y th│e ne│xt s│tep │
#     00000020  31 34 0a e2  94 83 20 50  6c 65 61 73  65 20 73 65  │14··│·· P│leas│e se│
#     00000030  6e 64 20 74  68 65 20 66  28 31 33 32  38 33 34 29  │nd t│he f│(132│834)│
#     00000040  3a 0a                                               │:·│
#     00000042
# 45
# 15849881229564464483851917797780797256637672
# [DEBUG] Sent 0x2d bytes:
#     b'15849881229564464483851917797780797256637672\n'
# [DEBUG] Received 0x42 bytes:
#     00000000  e2 94 83 20  47 6f 6f 64  20 6a 6f 62  2c 20 74 72  │··· │Good│ job│, tr│
#     00000010  79 20 74 68  65 20 6e 65  78 74 20 73  74 65 70 20  │y th│e ne│xt s│tep │
#     00000020  31 35 0a e2  94 83 20 50  6c 65 61 73  65 20 73 65  │15··│·· P│leas│e se│
#     00000030  6e 64 20 74  68 65 20 66  28 34 30 34  33 31 36 29  │nd t│he f│(404│316)│
#     00000040  3a 0a                                               │:·│
#     00000042
# 45
# 48243111996284924887258401347145205581863154
# [DEBUG] Sent 0x2d bytes:
#     b'48243111996284924887258401347145205581863154\n'
# [DEBUG] Received 0x42 bytes:
#     00000000  e2 94 83 20  47 6f 6f 64  20 6a 6f 62  2c 20 74 72  │··· │Good│ job│, tr│
#     00000010  79 20 74 68  65 20 6e 65  78 74 20 73  74 65 70 20  │y th│e ne│xt s│tep │
#     00000020  31 36 0a e2  94 83 20 50  6c 65 61 73  65 20 73 65  │16··│·· P│leas│e se│
#     00000030  6e 64 20 74  68 65 20 66  28 34 36 32  34 35 37 29  │nd t│he f│(462│457)│
#     00000040  3a 0a                                               │:·│
#     00000042
# 45
# 55180495800765127214906114123843462057198295
# [DEBUG] Sent 0x2d bytes:
#     b'55180495800765127214906114123843462057198295\n'
# [DEBUG] Received 0x43 bytes:
#     00000000  e2 94 83 20  47 6f 6f 64  20 6a 6f 62  2c 20 74 72  │··· │Good│ job│, tr│
#     00000010  79 20 74 68  65 20 6e 65  78 74 20 73  74 65 70 20  │y th│e ne│xt s│tep │
#     00000020  31 37 0a e2  94 83 20 50  6c 65 61 73  65 20 73 65  │17··│·· P│leas│e se│
#     00000030  6e 64 20 74  68 65 20 66  28 31 37 31  36 39 37 36  │nd t│he f│(171│6976│
#     00000040  29 3a 0a                                            │):·│
#     00000043
# 45
# 204869696072736695366095137100928823767195814
# [DEBUG] Sent 0x2e bytes:
#     b'204869696072736695366095137100928823767195814\n'
# [DEBUG] Received 0x23 bytes:
#     00000000  e2 94 83 20  47 6f 6f 64  20 6a 6f 62  2c 20 74 72  │··· │Good│ job│, tr│
#     00000010  79 20 74 68  65 20 6e 65  78 74 20 73  74 65 70 20  │y th│e ne│xt s│tep │
#     00000020  31 38 0a                                            │18·│
#     00000023
# [DEBUG] Received 0x20 bytes:
#     00000000  e2 94 83 20  50 6c 65 61  73 65 20 73  65 6e 64 20  │··· │Plea│se s│end │
#     00000010  74 68 65 20  66 28 34 31  32 31 36 36  31 29 3a 0a  │the │f(41│2166│1):·│
#     00000020
# 45
# 491796697222983084906342814272540025370045499
# [DEBUG] Sent 0x2e bytes:
#     b'491796697222983084906342814272540025370045499\n'
# [DEBUG] Received 0x43 bytes:
#     00000000  e2 94 83 20  47 6f 6f 64  20 6a 6f 62  2c 20 74 72  │··· │Good│ job│, tr│
#     00000010  79 20 74 68  65 20 6e 65  78 74 20 73  74 65 70 20  │y th│e ne│xt s│tep │
#     00000020  31 39 0a e2  94 83 20 50  6c 65 61 73  65 20 73 65  │19··│·· P│leas│e se│
#     00000030  6e 64 20 74  68 65 20 66  28 36 39 37  39 31 37 35  │nd t│he f│(697│9175│
#     00000040  29 3a 0a                                            │):·│
#     00000043
# 45
# 832755252195815352567475686555337735314161013
# [DEBUG] Sent 0x2e bytes:
#     b'832755252195815352567475686555337735314161013\n'
# [DEBUG] Received 0x44 bytes:
#     00000000  e2 94 83 20  47 6f 6f 64  20 6a 6f 62  2c 20 74 72  │··· │Good│ job│, tr│
#     00000010  79 20 74 68  65 20 6e 65  78 74 20 73  74 65 70 20  │y th│e ne│xt s│tep │
#     00000020  32 30 0a e2  94 83 20 50  6c 65 61 73  65 20 73 65  │20··│·· P│leas│e se│
#     00000030  6e 64 20 74  68 65 20 66  28 31 32 35  32 33 39 36  │nd t│he f│(125│2396│
#     00000040  34 29 3a 0a                                         │4):·│
#     00000044
# 45
# 1494359445585333533956090152756399788316638802
# [DEBUG] Sent 0x2f bytes:
#     b'1494359445585333533956090152756399788316638802\n'
# [DEBUG] Received 0x94 bytes:
#     00000000  e2 94 83 20  43 6f 6e 67  72 61 74 7a  21 20 59 6f  │··· │Cong│ratz│! Yo│
#     00000010  75 20 67 6f  74 20 74 68  65 20 66 6c  61 67 3a 20  │u go│t th│e fl│ag: │
#     00000020  62 27 43 43  54 46 7b 41  5f 66 75 6e  43 74 69 30  │b'CC│TF{A│_fun│Cti0│
#     00000030  6e 61 6c 5f  33 71 75 34  74 69 4f 6e  5f 69 5a 5f  │nal_│3qu4│tiOn│_iZ_│
#     00000040  34 5f 37 79  50 65 5f 6f  46 5f 45 71  75 41 74 69  │4_7y│Pe_o│F_Eq│uAti│
#     00000050  6f 4e 5f 74  48 61 54 5f  69 6e 76 30  6c 56 65 35  │oN_t│HaT_│inv0│lVe5│
#     00000060  5f 61 6e 5f  75 6e 4b 6e  4f 77 6e 5f  66 75 6e 43  │_an_│unKn│Own_│funC│
#     00000070  74 21 6f 6e  5f 72 34 74  48 33 72 5f  74 68 41 6e  │t!on│_r4t│H3r_│thAn│
#     00000080  5f 6a 75 53  37 5f 76 41  72 49 61 62  6c 33 73 21  │_juS│7_vA│rIab│l3s!│
#     00000090  21 7d 27 0a                                         │!}'·│
#     00000094
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# /tmp/ipykernel_22780/1226444882.py in <module>
#      31 f.recvline()
#      32 for i in range(10000):
# ---> 33     fx_match = re.search(r'f\((\d+)\):', f.recvline().decode())
#      34     y = int(fx_match.group(1))
#      35     print(x)
#
# ~/.local/lib/python3.10/site-packages/pwnlib/tubes/tube.py in recvline(self, keepends, timeout)
#     496             b'Foo\nBar'
#     497         """
# --> 498         return self.recvuntil(self.newline, drop = not keepends, timeout = timeout)
#     499
#     500     def recvline_pred(self, pred, keepends=False, timeout=default):
#
# ~/.local/lib/python3.10/site-packages/pwnlib/tubes/tube.py in recvuntil(self, delims, drop, timeout)
#     339             while self.countdown_active():
#     340                 try:
# --> 341                     res = self.recv(timeout=self.timeout)
#     342                 except Exception:
#     343                     self.unrecv(b''.join(data) + top)
#
# ~/.local/lib/python3.10/site-packages/pwnlib/tubes/tube.py in recv(self, numb, timeout)
#     104         """
#     105         numb = self.buffer.get_fill_size(numb)
# --> 106         return self._recv(numb, timeout) or b''
#     107
#     108     def unrecv(self, data):
#
# ~/.local/lib/python3.10/site-packages/pwnlib/tubes/tube.py in _recv(self, numb, timeout)
#     174         # No buffered data, could not put anything in the buffer
#     175         # before timeout.
# --> 176         if not self.buffer and not self._fillbuffer(timeout):
#     177             return b''
#     178
#
# ~/.local/lib/python3.10/site-packages/pwnlib/tubes/tube.py in _fillbuffer(self, timeout)
#     153
#     154         with self.local(timeout):
# --> 155             data = self.recv_raw(self.buffer.get_fill_size())
#     156
#     157         if data and self.isEnabledFor(logging.DEBUG):
#
# ~/.local/lib/python3.10/site-packages/pwnlib/tubes/sock.py in recv_raw(self, numb, *a)
#      54         if not data:
#      55             self.shutdown("recv")
# ---> 56             raise EOFError
#      57
#      58         return data
#
# EOFError:
