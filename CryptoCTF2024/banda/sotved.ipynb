# %%
from pwn import *
from z3 import *

f = remote("00.cr.yp.toc.tf", 17113)
context.log_level = "DEBUG"

def find_xy(n):
    arr = []
    for a in range(1, int(2*n**0.5) + 1):
        if (2*n) % a == 0:
            b = (2*n) // a
            if (a + b + 1) % 2 == 0 and (b - a + 1) % 2 == 0:
                x = (a + b + 1) // 2
                y = (b - a + 1) // 2
                if x >= 1 and y >= 1:
                    arr.append((x, y))
    return arr

while True:
    res = f.recvuntil(b'f(1, 1) = ').decode()
    res += f.recvuntil(b' and f(x, y) = ').decode()
    f11 = int(res.split('f(1, 1) = ')[1].split(' ')[0])
    print(f"f(1, 1) = {f11}")

    fxy = int(f.recvline().strip().decode())
    print(f"f(x, y) = {fxy}")

    result = find_xy(fxy - f11)
    if result:
        print(f"[Y] Found solutions: {result}")
    else:
        print("[N] No solution found.")

    for x, y in result:
        f.sendline(f"{x},{y}")
        break
    print(f"[+] Sent: {x},{y}")
# Out:
# [x] Opening connection to 00.cr.yp.toc.tf on port 17113
# [x] Opening connection to 00.cr.yp.toc.tf on port 17113: Trying 65.109.213.236
# [+] Opening connection to 00.cr.yp.toc.tf on port 17113: Done
# [DEBUG] Received 0x2e6 bytes:
#     00000000  e2 94 8f e2  94 81 e2 94  81 e2 94 81  e2 94 81 e2  │····│····│····│····│
#     00000010  94 81 e2 94  81 e2 94 81  e2 94 81 e2  94 81 e2 94  │····│····│····│····│
#     00000020  81 e2 94 81  e2 94 81 e2  94 81 e2 94  81 e2 94 81  │····│····│····│····│
#     00000030  e2 94 81 e2  94 81 e2 94  81 e2 94 81  e2 94 81 e2  │····│····│····│····│
#     00000040  94 81 e2 94  81 e2 94 81  e2 94 81 e2  94 81 e2 94  │····│····│····│····│
#     00000050  81 e2 94 81  e2 94 81 e2  94 81 e2 94  81 e2 94 81  │····│····│····│····│
#     00000060  e2 94 81 e2  94 81 e2 94  81 e2 94 81  e2 94 81 e2  │····│····│····│····│
#     00000070  94 81 e2 94  81 e2 94 81  e2 94 81 e2  94 81 e2 94  │····│····│····│····│
#     00000080  81 e2 94 81  e2 94 81 e2  94 81 e2 94  81 e2 94 81  │····│····│····│····│
#     00000090  e2 94 81 e2  94 81 e2 94  81 e2 94 81  e2 94 81 e2  │····│····│····│····│
#     000000a0  94 81 e2 94  81 e2 94 81  e2 94 81 e2  94 81 e2 94  │····│····│····│····│
#     000000b0  81 e2 94 81  e2 94 81 e2  94 81 e2 94  81 e2 94 81  │····│····│····│····│
#     000000c0  e2 94 81 e2  94 81 e2 94  81 e2 94 81  e2 94 81 e2  │····│····│····│····│
#     000000d0  94 81 e2 94  81 e2 94 93  0a e2 94 83  20 48 65 79  │····│····│····│ Hey│
#     000000e0  21 20 49 74  27 73 20 74  69 6d 65 20  74 6f 20 73  │! It│'s t│ime │to s│
#     000000f0  6f 6c 76 65  20 74 68 65  20 65 71 75  61 74 69 6f  │olve│ the│ equ│atio│
#     00000100  6e 20 6f 66  20 61 20 66  75 6e 63 74  69 6f 6e 20  │n of│ a f│unct│ion │
#     00000110  66 3a 20 4e  20 78 20 4e  20 2d 3e 20  5a 2e 20 20  │f: N│ x N│ -> │Z.  │
#     00000120  20 20 e2 94  83 0a e2 94  83 20 46 75  6e 63 74 69  │  ··│····│· Fu│ncti│
#     00000130  6f 6e 20 66  20 68 61 73  20 67 69 76  65 6e 20 63  │on f│ has│ giv│en c│
#     00000140  65 72 74 61  69 6e 20 63  6f 6e 64 69  74 69 6f 6e  │erta│in c│ondi│tion│
#     00000150  73 2e 20 49  6e 20 65 61  63 68 20 73  74 65 70 2c  │s. I│n ea│ch s│tep,│
#     00000160  20 73 6f 6c  76 65 20 74  68 65 20 20  20 20 20 e2  │ sol│ve t│he  │   ·│
#     00000170  94 83 0a e2  94 83 20 65  71 75 61 74  69 6f 6e 20  │····│·· e│quat│ion │
#     00000180  66 28 78 2c  20 79 29 20  3d 20 7a 20  77 69 74 68  │f(x,│ y) │= z │with│
#     00000190  20 74 68 65  20 67 69 76  65 6e 20 76  61 6c 75 65  │ the│ giv│en v│alue│
#     000001a0  20 6f 66 20  7a 2e 20 57  65 20 6b 6e  6f 77 20 66  │ of │z. W│e kn│ow f│
#     000001b0  28 61 2b 31  2c 20 62 29  20 3d 20 20  e2 94 83 0a  │(a+1│, b)│ =  │····│
#     000001c0  e2 94 83 20  66 28 61 2c  20 62 29 20  2b 20 61 2c  │··· │f(a,│ b) │+ a,│
#     000001d0  20 61 6e 64  20 66 28 61  2c 20 62 2b  31 29 20 3d  │ and│ f(a│, b+│1) =│
#     000001e0  20 66 28 61  2c 20 62 29  20 2d 20 62  2c 20 66 6f  │ f(a│, b)│ - b│, fo│
#     000001f0  72 20 65 76  65 72 79 20  60 61 27 20  61 6e 64 20  │r ev│ery │`a' │and │
#     00000200  60 62 27 2e  20 20 20 20  20 e2 94 83  0a e2 94 97  │`b'.│    │ ···│····│
#     00000210  e2 94 81 e2  94 81 e2 94  81 e2 94 81  e2 94 81 e2  │····│····│····│····│
#     00000220  94 81 e2 94  81 e2 94 81  e2 94 81 e2  94 81 e2 94  │····│····│····│····│
#     00000230  81 e2 94 81  e2 94 81 e2  94 81 e2 94  81 e2 94 81  │····│····│····│····│
#     00000240  e2 94 81 e2  94 81 e2 94  81 e2 94 81  e2 94 81 e2  │····│····│····│····│
#     00000250  94 81 e2 94  81 e2 94 81  e2 94 81 e2  94 81 e2 94  │····│····│····│····│
#     00000260  81 e2 94 81  e2 94 81 e2  94 81 e2 94  81 e2 94 81  │····│····│····│····│
#     00000270  e2 94 81 e2  94 81 e2 94  81 e2 94 81  e2 94 81 e2  │····│····│····│····│
#     00000280  94 81 e2 94  81 e2 94 81  e2 94 81 e2  94 81 e2 94  │····│····│····│····│
#     00000290  81 e2 94 81  e2 94 81 e2  94 81 e2 94  81 e2 94 81  │····│····│····│····│
#     000002a0  e2 94 81 e2  94 81 e2 94  81 e2 94 81  e2 94 81 e2  │····│····│····│····│
#     000002b0  94 81 e2 94  81 e2 94 81  e2 94 81 e2  94 81 e2 94  │····│····│····│····│
#     000002c0  81 e2 94 81  e2 94 81 e2  94 81 e2 94  81 e2 94 81  │····│····│····│····│
#     000002d0  e2 94 81 e2  94 81 e2 94  81 e2 94 81  e2 94 81 e2  │····│····│····│····│
#     000002e0  94 81 e2 94  9b 0a                                  │····│··│
#     000002e6
# [DEBUG] Received 0x6a bytes:
#     00000000  e2 94 83 20  57 65 20 6b  6e 6f 77 3a  20 66 28 31  │··· │We k│now:│ f(1│
#     00000010  2c 20 31 29  20 3d 20 35  34 33 38 35  30 34 37 39  │, 1)│ = 5│4385│0479│
#     00000020  39 31 37 20  61 6e 64 20  66 28 78 2c  20 79 29 20  │917 │and │f(x,│ y) │
#     00000030  3d 20 31 33  37 32 37 34  39 37 38 32  34 38 38 0a  │= 13│7274│9782│488·│
#     00000040  e2 94 83 20  50 6c 65 61  73 65 20 73  65 6e 64 20  │··· │Plea│se s│end │
#     00000050  78 2c 20 79  20 73 65 70  61 72 61 74  65 64 20 62  │x, y│ sep│arat│ed b│
#     00000060  79 20 63 6f  6d 6d 61 3a  20 0a                     │y co│mma:│ ·│
#     0000006a
# f(1, 1) = 543850479917
# f(x, y) = 1372749782488
# [Y] Found solutions: [(828899302572, 828899302571), (414449651287, 414449651285)]
# [DEBUG] Sent 0x1a bytes:
#     b'828899302572,828899302571\n'
# [+] Sent: 828899302572,828899302571
# /tmp/ipykernel_64419/1630576784.py:35: BytesWarning: Text is not bytes; assuming ASCII, no guarantees. See https://docs.pwntools.com/#bytes
#   f.sendline(f"{x},{y}")
# [DEBUG] Received 0x26 bytes:
#     00000000  e2 94 83 20  47 6f 6f 64  20 6a 6f 62  2c 20 74 72  │··· │Good│ job│, tr│
#     00000010  79 20 74 68  65 20 6e 65  78 74 20 6c  65 76 65 6c  │y th│e ne│xt l│evel│
#     00000020  20 32 20 3a  29 0a                                  │ 2 :│)·│
#     00000026
# [DEBUG] Received 0x41 bytes:
#     00000000  e2 94 83 20  57 65 20 6b  6e 6f 77 3a  20 66 28 31  │··· │We k│now:│ f(1│
#     00000010  2c 20 31 29  20 3d 20 2d  38 39 30 31  31 38 34 36  │, 1)│ = -│8901│1846│
#     00000020  39 32 33 36  20 61 6e 64  20 66 28 78  2c 20 79 29  │9236│ and│ f(x│, y)│
#     00000030  20 3d 20 32  37 34 38 30  39 31 39 38  30 37 34 35  │ = 2│7480│9198│0745│
#     00000040  0a                                                  │·│
#     00000041
# f(1, 1) = -890118469236
# f(x, y) = 2748091980745
# [Y] Found solutions: [(3638210449982, 3638210449981), (1819105224992, 1819105224990)]
# [DEBUG] Sent 0x1c bytes:
#     b'3638210449982,3638210449981\n'
# [+] Sent: 3638210449982,3638210449981
# [DEBUG] Received 0xbc bytes:
#     00000000  e2 94 83 20  50 6c 65 61  73 65 20 73  65 6e 64 20  │··· │Plea│se s│end │
#     00000010  78 2c 20 79  20 73 65 70  61 72 61 74  65 64 20 62  │x, y│ sep│arat│ed b│
#     00000020  79 20 63 6f  6d 6d 61 3a  20 0a e2 94  83 20 47 6f  │y co│mma:│ ···│· Go│
#     00000030  6f 64 20 6a  6f 62 2c 20  74 72 79 20  74 68 65 20  │od j│ob, │try │the │
#     00000040  6e 65 78 74  20 6c 65 76  65 6c 20 33  20 3a 29 0a  │next│ lev│el 3│ :)·│
#     00000050  e2 94 83 20  57 65 20 6b  6e 6f 77 3a  20 66 28 31  │··· │We k│now:│ f(1│
#     00000060  2c 20 31 29  20 3d 20 36  39 34 38 32  37 36 38 39  │, 1)│ = 6│9482│7689│
#     00000070  33 39 31 39  20 61 6e 64  20 66 28 78  2c 20 79 29  │3919│ and│ f(x│, y)│
#     00000080  20 3d 20 31  36 32 36 31  32 36 37 32  34 34 31 39  │ = 1│6261│2672│4419│
#     00000090  32 0a e2 94  83 20 50 6c  65 61 73 65  20 73 65 6e  │2···│· Pl│ease│ sen│
#     000000a0  64 20 78 2c  20 79 20 73  65 70 61 72  61 74 65 64  │d x,│ y s│epar│ated│
#     000000b0  20 62 79 20  63 6f 6d 6d  61 3a 20 0a               │ by │comm│a: ·│
#     000000bc
# f(1, 1) = 6948276893919
# f(x, y) = 16261267244192
# [Y] Found solutions: [(9312990350274, 9312990350273), (4656495175138, 4656495175136)]
# [DEBUG] Sent 0x1c bytes:
#     b'9312990350274,9312990350273\n'
# [+] Sent: 9312990350274,9312990350273
# [DEBUG] Received 0x26 bytes:
#     00000000  e2 94 83 20  47 6f 6f 64  20 6a 6f 62  2c 20 74 72  │··· │Good│ job│, tr│
#     00000010  79 20 74 68  65 20 6e 65  78 74 20 6c  65 76 65 6c  │y th│e ne│xt l│evel│
#     00000020  20 34 20 3a  29 0a                                  │ 4 :│)·│
#     00000026
# [DEBUG] Received 0x6d bytes:
#     00000000  e2 94 83 20  57 65 20 6b  6e 6f 77 3a  20 66 28 31  │··· │We k│now:│ f(1│
#     00000010  2c 20 31 29  20 3d 20 2d  31 32 35 32  33 32 37 36  │, 1)│ = -│1252│3276│
#     00000020  38 31 34 33  32 20 61 6e  64 20 66 28  78 2c 20 79  │8143│2 an│d f(│x, y│
#     00000030  29 20 3d 20  34 34 39 38  33 38 33 38  30 32 37 30  │) = │4498│3838│0270│
#     00000040  39 37 0a e2  94 83 20 50  6c 65 61 73  65 20 73 65  │97··│·· P│leas│e se│
#     00000050  6e 64 20 78  2c 20 79 20  73 65 70 61  72 61 74 65  │nd x│, y │sepa│rate│
#     00000060  64 20 62 79  20 63 6f 6d  6d 61 3a 20  0a           │d by│ com│ma: │·│
#     0000006d
# f(1, 1) = -1252327681432
# f(x, y) = 44983838027097
# [Y] Found solutions: [(46236165708530, 46236165708529), (23118082854266, 23118082854264)]
# [DEBUG] Sent 0x1e bytes:
#     b'46236165708530,46236165708529\n'
# [+] Sent: 46236165708530,46236165708529
# [DEBUG] Received 0x26 bytes:
#     00000000  e2 94 83 20  47 6f 6f 64  20 6a 6f 62  2c 20 74 72  │··· │Good│ job│, tr│
#     00000010  79 20 74 68  65 20 6e 65  78 74 20 6c  65 76 65 6c  │y th│e ne│xt l│evel│
#     00000020  20 35 20 3a  29 0a                                  │ 5 :│)·│
#     00000026
# [DEBUG] Received 0x6f bytes:
#     00000000  e2 94 83 20  57 65 20 6b  6e 6f 77 3a  20 66 28 31  │··· │We k│now:│ f(1│
#     00000010  2c 20 31 29  20 3d 20 2d  32 33 36 37  36 37 33 31  │, 1)│ = -│2367│6731│
#     00000020  35 30 35 37  36 32 35 20  61 6e 64 20  66 28 78 2c  │5057│625 │and │f(x,│
#     00000030  20 79 29 20  3d 20 31 38  32 39 38 35  32 33 33 30  │ y) │= 18│2985│2330│
#     00000040  35 37 36 34  0a e2 94 83  20 50 6c 65  61 73 65 20  │5764│····│ Ple│ase │
#     00000050  73 65 6e 64  20 78 2c 20  79 20 73 65  70 61 72 61  │send│ x, │y se│para│
#     00000060  74 65 64 20  62 79 20 63  6f 6d 6d 61  3a 20 0a     │ted │by c│omma│: ·│
#     0000006f
# f(1, 1) = -236767315057625
# f(x, y) = 18298523305764
# [Y] Found solutions: [(255065838363390, 255065838363389), (127532919181696, 127532919181694)]
# [DEBUG] Sent 0x20 bytes:
#     b'255065838363390,255065838363389\n'
# [+] Sent: 255065838363390,255065838363389
# [DEBUG] Received 0x26 bytes:
#     00000000  e2 94 83 20  47 6f 6f 64  20 6a 6f 62  2c 20 74 72  │··· │Good│ job│, tr│
#     00000010  79 20 74 68  65 20 6e 65  78 74 20 6c  65 76 65 6c  │y th│e ne│xt l│evel│
#     00000020  20 36 20 3a  29 0a                                  │ 6 :│)·│
#     00000026
# [DEBUG] Received 0x70 bytes:
#     00000000  e2 94 83 20  57 65 20 6b  6e 6f 77 3a  20 66 28 31  │··· │We k│now:│ f(1│
#     00000010  2c 20 31 29  20 3d 20 35  34 30 36 33  33 35 35 35  │, 1)│ = 5│4063│3555│
#     00000020  33 31 30 31  34 37 20 61  6e 64 20 66  28 78 2c 20  │3101│47 a│nd f│(x, │
#     00000030  79 29 20 3d  20 31 34 33  37 37 37 34  33 38 39 38  │y) =│ 143│7774│3898│
#     00000040  34 39 35 39  34 0a e2 94  83 20 50 6c  65 61 73 65  │4959│4···│· Pl│ease│
#     00000050  20 73 65 6e  64 20 78 2c  20 79 20 73  65 70 61 72  │ sen│d x,│ y s│epar│
#     00000060  61 74 65 64  20 62 79 20  63 6f 6d 6d  61 3a 20 0a  │ated│ by │comm│a: ·│
#     00000070
# f(1, 1) = 540633555310147
# f(x, y) = 1437774389849594
# [Y] Found solutions: [(897140834539448, 897140834539447), (448570417269725, 448570417269723)]
# [DEBUG] Sent 0x20 bytes:
#     b'897140834539448,897140834539447\n'
# [+] Sent: 897140834539448,897140834539447
# [DEBUG] Received 0x26 bytes:
#     00000000  e2 94 83 20  47 6f 6f 64  20 6a 6f 62  2c 20 74 72  │··· │Good│ job│, tr│
#     00000010  79 20 74 68  65 20 6e 65  78 74 20 6c  65 76 65 6c  │y th│e ne│xt l│evel│
#     00000020  20 37 20 3a  29 0a                                  │ 7 :│)·│
#     00000026
# [DEBUG] Received 0x71 bytes:
#     00000000  e2 94 83 20  57 65 20 6b  6e 6f 77 3a  20 66 28 31  │··· │We k│now:│ f(1│
#     00000010  2c 20 31 29  20 3d 20 31  30 31 30 33  32 31 31 31  │, 1)│ = 1│0103│2111│
#     00000020  32 37 35 31  38 31 32 20  61 6e 64 20  66 28 78 2c  │2751│812 │and │f(x,│
#     00000030  20 79 29 20  3d 20 33 38  33 38 35 32  37 32 33 32  │ y) │= 38│3852│7232│
#     00000040  36 38 32 30  33 39 0a e2  94 83 20 50  6c 65 61 73  │6820│39··│·· P│leas│
#     00000050  65 20 73 65  6e 64 20 78  2c 20 79 20  73 65 70 61  │e se│nd x│, y │sepa│
#     00000060  72 61 74 65  64 20 62 79  20 63 6f 6d  6d 61 3a 20  │rate│d by│ com│ma: │
#     00000070  0a                                                  │·│
#     00000071
# f(1, 1) = 1010321112751812
# f(x, y) = 3838527232682039
# [Y] Found solutions: [(2828206119930228, 2828206119930227), (1414103059965115, 1414103059965113)]
# [DEBUG] Sent 0x22 bytes:
#     b'2828206119930228,2828206119930227\n'
# [+] Sent: 2828206119930228,2828206119930227
# [DEBUG] Received 0x26 bytes:
#     00000000  e2 94 83 20  47 6f 6f 64  20 6a 6f 62  2c 20 74 72  │··· │Good│ job│, tr│
#     00000010  79 20 74 68  65 20 6e 65  78 74 20 6c  65 76 65 6c  │y th│e ne│xt l│evel│
#     00000020  20 38 20 3a  29 0a                                  │ 8 :│)·│
#     00000026
# [DEBUG] Received 0x71 bytes:
#     00000000  e2 94 83 20  57 65 20 6b  6e 6f 77 3a  20 66 28 31  │··· │We k│now:│ f(1│
#     00000010  2c 20 31 29  20 3d 20 38  36 35 35 35  37 34 38 32  │, 1)│ = 8│6555│7482│
#     00000020  30 38 38 38  34 34 20 61  6e 64 20 66  28 78 2c 20  │0888│44 a│nd f│(x, │
#     00000030  79 29 20 3d  20 31 31 36  36 32 35 31  38 38 34 38  │y) =│ 116│6251│8848│
#     00000040  39 31 37 36  36 35 0a e2  94 83 20 50  6c 65 61 73  │9176│65··│·· P│leas│
#     00000050  65 20 73 65  6e 64 20 78  2c 20 79 20  73 65 70 61  │e se│nd x│, y │sepa│
#     00000060  72 61 74 65  64 20 62 79  20 63 6f 6d  6d 61 3a 20  │rate│d by│ com│ma: │
#     00000070  0a                                                  │·│
#     00000071
# f(1, 1) = 865557482088844
# f(x, y) = 11662518848917665
# [Y] Found solutions: [(10796961366828822, 10796961366828821), (5398480683414412, 5398480683414410)]
# [DEBUG] Sent 0x24 bytes:
#     b'10796961366828822,10796961366828821\n'
# [+] Sent: 10796961366828822,10796961366828821
# [DEBUG] Received 0x26 bytes:
#     00000000  e2 94 83 20  47 6f 6f 64  20 6a 6f 62  2c 20 74 72  │··· │Good│ job│, tr│
#     00000010  79 20 74 68  65 20 6e 65  78 74 20 6c  65 76 65 6c  │y th│e ne│xt l│evel│
#     00000020  20 39 20 3a  29 0a                                  │ 9 :│)·│
#     00000026
# [DEBUG] Received 0x74 bytes:
#     00000000  e2 94 83 20  57 65 20 6b  6e 6f 77 3a  20 66 28 31  │··· │We k│now:│ f(1│
#     00000010  2c 20 31 29  20 3d 20 2d  32 34 34 30  36 35 34 34  │, 1)│ = -│2440│6544│
#     00000020  38 30 39 37  32 32 38 37  33 20 61 6e  64 20 66 28  │8097│2287│3 an│d f(│
#     00000030  78 2c 20 79  29 20 3d 20  32 35 35 36  30 30 38 34  │x, y│) = │2556│0084│
#     00000040  30 37 31 39  32 38 31 37  36 0a e2 94  83 20 50 6c  │0719│2817│6···│· Pl│
#     00000050  65 61 73 65  20 73 65 6e  64 20 78 2c  20 79 20 73  │ease│ sen│d x,│ y s│
#     00000060  65 70 61 72  61 74 65 64  20 62 79 20  63 6f 6d 6d  │epar│ated│ by │comm│
#     00000070  61 3a 20 0a                                         │a: ·│
#     00000074
# f(1, 1) = -24406544809722873
# f(x, y) = 25560084071928176
# [Y] Found solutions: [(49966628881651050, 49966628881651049), (24983314440825526, 24983314440825524)]
# [DEBUG] Sent 0x24 bytes:
#     b'49966628881651050,49966628881651049\n'
# [+] Sent: 49966628881651050,49966628881651049
# [DEBUG] Received 0x27 bytes:
#     00000000  e2 94 83 20  47 6f 6f 64  20 6a 6f 62  2c 20 74 72  │··· │Good│ job│, tr│
#     00000010  79 20 74 68  65 20 6e 65  78 74 20 6c  65 76 65 6c  │y th│e ne│xt l│evel│
#     00000020  20 31 30 20  3a 29 0a                               │ 10 │:)·│
#     00000027
# [DEBUG] Received 0x75 bytes:
#     00000000  e2 94 83 20  57 65 20 6b  6e 6f 77 3a  20 66 28 31  │··· │We k│now:│ f(1│
#     00000010  2c 20 31 29  20 3d 20 31  36 38 33 36  30 39 34 36  │, 1)│ = 1│6836│0946│
#     00000020  30 31 34 35  36 33 39 38  32 20 61 6e  64 20 66 28  │0145│6398│2 an│d f(│
#     00000030  78 2c 20 79  29 20 3d 20  34 34 34 37  35 33 33 39  │x, y│) = │4447│5339│
#     00000040  32 37 38 38  30 37 30 38  39 31 0a e2  94 83 20 50  │2788│0708│91··│·· P│
#     00000050  6c 65 61 73  65 20 73 65  6e 64 20 78  2c 20 79 20  │leas│e se│nd x│, y │
#     00000060  73 65 70 61  72 61 74 65  64 20 62 79  20 63 6f 6d  │sepa│rate│d by│ com│
#     00000070  6d 61 3a 20  0a                                     │ma: │·│
#     00000075
# f(1, 1) = 168360946014563982
# f(x, y) = 444753392788070891
# [Y] Found solutions: [(276392446773506910, 276392446773506909), (138196223386753456, 138196223386753454)]
# [DEBUG] Sent 0x26 bytes:
#     b'276392446773506910,276392446773506909\n'
# [+] Sent: 276392446773506910,276392446773506909
# [DEBUG] Received 0x9d bytes:
#     00000000  e2 94 83 20  47 6f 6f 64  20 6a 6f 62  2c 20 74 72  │··· │Good│ job│, tr│
#     00000010  79 20 74 68  65 20 6e 65  78 74 20 6c  65 76 65 6c  │y th│e ne│xt l│evel│
#     00000020  20 31 31 20  3a 29 0a e2  94 83 20 57  65 20 6b 6e  │ 11 │:)··│·· W│e kn│
#     00000030  6f 77 3a 20  66 28 31 2c  20 31 29 20  3d 20 2d 32  │ow: │f(1,│ 1) │= -2│
#     00000040  31 33 36 31  30 39 32 35  35 38 30 30  31 30 34 31  │1361│0925│5800│1041│
#     00000050  31 20 61 6e  64 20 66 28  78 2c 20 79  29 20 3d 20  │1 an│d f(│x, y│) = │
#     00000060  33 39 37 37  37 31 30 31  33 32 39 33  33 31 37 34  │3977│7101│3293│3174│
#     00000070  37 32 0a e2  94 83 20 50  6c 65 61 73  65 20 73 65  │72··│·· P│leas│e se│
#     00000080  6e 64 20 78  2c 20 79 20  73 65 70 61  72 61 74 65  │nd x│, y │sepa│rate│
#     00000090  64 20 62 79  20 63 6f 6d  6d 61 3a 20  0a           │d by│ com│ma: │·│
#     0000009d
# f(1, 1) = -213610925580010411
# f(x, y) = 397771013293317472
# [Y] Found solutions: [(611381938873327884, 611381938873327883), (305690969436663943, 305690969436663941)]
# [DEBUG] Sent 0x26 bytes:
#     b'611381938873327884,611381938873327883\n'
# [+] Sent: 611381938873327884,611381938873327883
# [DEBUG] Received 0x27 bytes:
#     00000000  e2 94 83 20  47 6f 6f 64  20 6a 6f 62  2c 20 74 72  │··· │Good│ job│, tr│
#     00000010  79 20 74 68  65 20 6e 65  78 74 20 6c  65 76 65 6c  │y th│e ne│xt l│evel│
#     00000020  20 31 32 20  3a 29 0a                               │ 12 │:)·│
#     00000027
# [DEBUG] Received 0x78 bytes:
#     00000000  e2 94 83 20  57 65 20 6b  6e 6f 77 3a  20 66 28 31  │··· │We k│now:│ f(1│
#     00000010  2c 20 31 29  20 3d 20 2d  31 35 31 34  36 39 37 37  │, 1)│ = -│1514│6977│
#     00000020  30 30 36 36  35 30 37 37  37 33 34 20  61 6e 64 20  │0066│5077│734 │and │
#     00000030  66 28 78 2c  20 79 29 20  3d 20 31 30  33 36 30 36  │f(x,│ y) │= 10│3606│
#     00000040  36 34 39 38  32 36 35 30  34 36 35 36  35 0a e2 94  │6498│2650│4656│5···│
#     00000050  83 20 50 6c  65 61 73 65  20 73 65 6e  64 20 78 2c  │· Pl│ease│ sen│d x,│
#     00000060  20 79 20 73  65 70 61 72  61 74 65 64  20 62 79 20  │ y s│epar│ated│ by │
#     00000070  63 6f 6d 6d  61 3a 20 0a                            │comm│a: ·│
#     00000078
# f(1, 1) = -1514697700665077734
# f(x, y) = 1036066498265046565
# [Y] Found solutions: [(2550764198930124300, 2550764198930124299), (1275382099465062151, 1275382099465062149)]
# [DEBUG] Sent 0x28 bytes:
#     b'2550764198930124300,2550764198930124299\n'
# [+] Sent: 2550764198930124300,2550764198930124299
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# /tmp/ipykernel_64419/1630576784.py in <module>
#      18
#      19 while True:
# ---> 20     res = f.recvuntil(b'f(1, 1) = ').decode()
#      21     res += f.recvuntil(b' and f(x, y) = ').decode()
#      22     f11 = int(res.split('f(1, 1) = ')[1].split(' ')[0])
#
# ~/.local/lib/python3.10/site-packages/pwnlib/tubes/tube.py in recvuntil(self, delims, drop, timeout)
#     339             while self.countdown_active():
#     340                 try:
# --> 341                     res = self.recv(timeout=self.timeout)
#     342                 except Exception:
#     343                     self.unrecv(b''.join(data) + top)
#
# ~/.local/lib/python3.10/site-packages/pwnlib/tubes/tube.py in recv(self, numb, timeout)
#     104         """
#     105         numb = self.buffer.get_fill_size(numb)
# --> 106         return self._recv(numb, timeout) or b''
#     107
#     108     def unrecv(self, data):
#
# ~/.local/lib/python3.10/site-packages/pwnlib/tubes/tube.py in _recv(self, numb, timeout)
#     174         # No buffered data, could not put anything in the buffer
#     175         # before timeout.
# --> 176         if not self.buffer and not self._fillbuffer(timeout):
#     177             return b''
#     178
#
# ~/.local/lib/python3.10/site-packages/pwnlib/tubes/tube.py in _fillbuffer(self, timeout)
#     153
#     154         with self.local(timeout):
# --> 155             data = self.recv_raw(self.buffer.get_fill_size())
#     156
#     157         if data and self.isEnabledFor(logging.DEBUG):
#
# ~/.local/lib/python3.10/site-packages/pwnlib/tubes/sock.py in recv_raw(self, numb, *a)
#      54         if not data:
#      55             self.shutdown("recv")
# ---> 56             raise EOFError
#      57
#      58         return data
#
# EOFError:

# %%
def find_xy(n):
    arr = []
    for a in range(1, int(2*n**0.5) + 1):
        if (2*n) % a == 0:
            b = (2*n) // a
            if (a + b + 1) % 2 == 0 and (b - a + 1) % 2 == 0:
                x = (a + b + 1) // 2
                y = (b - a + 1) // 2
                if x >= 1 and y >= 1:
                    arr.append((x, y))
    return arr

f11 = -141669333002
fxy = 816415434909
result = find_xy(fxy - f11)
assert result
print(result)
