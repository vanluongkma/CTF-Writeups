# %%
from pwn import *
from randcrack import RandCrack
from Crypto.Util.number import long_to_bytes

rc = RandCrack()
p = remote('20.80.240.190', 4447, level = 'debug')
username = "0" * 25 + b'\xe1\x94\x89'.decode()
p.sendlinethen(b'IV used during this session:  ', username.encode())
iv = bytearray.fromhex(p.recvline(keepends=False).decode())
for _ in range(624 // 4):
    iv[-1] ^= 2 ^ (48 + 1)
    iv[-2] ^= ord('C') ^ 0x8c
    p.recvuntil(b'Your new token is :  ')
    enc = bytearray.fromhex(p.recvline(keepends=False).decode())
    enc[79 - 16] ^= 1
    p.sendline(b'1')
    p.sendlinethen(b'encrypt is ', (iv + enc).hex().encode())
    randbits128 = bytes.fromhex(p.recvline()[:-2].decode())
    big = randbits128[::-1]
    for i in range(4):
        randbits32 = int.from_bytes(big[i * 4: i * 4 + 4], byteorder='little')
        rc.submit(randbits32)
rc.predict_getrandbits(128)
p.sendline(b'2')
p.sendline(long_to_bytes(rc.predict_getrandbits(128)).hex().encode())
p.interactive()
# Out:
# [x] Opening connection to 20.80.240.190 on port 4447
# [x] Opening connection to 20.80.240.190 on port 4447: Trying 20.80.240.190
# [+] Opening connection to 20.80.240.190 on port 4447: Done
# [DEBUG] Sent 0x1d bytes:
#     00000000  30 30 30 30  30 30 30 30  30 30 30 30  30 30 30 30  │0000│0000│0000│0000│
#     00000010  30 30 30 30  30 30 30 30  30 e1 94 89  0a           │0000│0000│0···│·│
#     0000001d
# [DEBUG] Received 0xb0 bytes:
#     b'What can I call you ? IV used during this session:  c3b446b7166b4b05c15383aa5b7f18af\n'
#     b'==========================================================================================\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0x245 bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 1 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is dfe8b6ef505963658471e1ce28ab3791.\n'
#     b'Thank you for using our service !\n'
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0x245 bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 2 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is 49dac33ea21197cec8412e24f288e570.\n'
#     b'Thank you for using our service !\n'
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0x245 bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 3 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is 2e83b1a80a48efd55d131db94f663ec2.\n'
#     b'Thank you for using our service !\n'
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfa bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 4 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is 41f0fbf2e90dfb3515ecc9d4df61e23b.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfa bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 5 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is b0ce757f44e4a71ef809a60a673b050c.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfa bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 6 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is b892a1d7e3590b9a78b91f582381a0d2.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0x5d bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 7 times.\n'
# [DEBUG] Received 0x1e8 bytes:
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is e93c256f3eaf7ac391e0b85cd9d9a60f.\n'
#     b'Thank you for using our service !\n'
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfa bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 8 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is 53bf83ea347e57f1ef1277c438ca51ce.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfa bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 9 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is 3d4d6c9f6fa8c2ded6d4e0ba25174153.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfb bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 10 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is c6599e3d5958213ed74dd04760df67c9.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfb bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 11 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is 2f99daf672d1b77446b7b24b4bda4b7a.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfb bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 12 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is 89b27bd2e281d0c6530185070d3e0eb9.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfb bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 13 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is b824d6994e6b25a0f5eee9410ac45c4b.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfb bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 14 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is 94a289ffca07dbe89318cb0e88e65670.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfb bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 15 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is 143ffd94f78d89b49cbaa36c6058362f.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfb bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 16 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is 17118811e24189b03d0a9760f4f7d0af.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfb bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 17 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is 77b4f49951def4e25ef41296b9f63d92.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfb bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 18 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is f62cc13104d9db1ad7f11b15ae146433.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfb bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 19 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is a741d7a54ae5d886dc5bc3bbc2bd3403.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfb bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 20 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is 535841cfde51a165b052069348181203.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfb bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 21 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is b3ebf914bd31bd19df1695f046bc5e2c.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfb bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 22 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is be0a6471e4df044aa150262a21bbef0e.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfb bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 23 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is e827341326471d9d38439cad714d4adc.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfb bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 24 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is 4e442264602fa11e298359dcee27ce61.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfb bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 25 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is d93337bcc7a2b0ee5a87151383842e9c.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfb bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 26 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is b7c35f02bbf181f570a4a7d60f76813f.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfb bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 27 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is 47defb993648d0a5738cf51842ab6a90.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfb bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 28 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is 3bdfb0b245f4c22daafef48280e6b403.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfb bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 29 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is 3af882f91ba725504ab4a36411cf125c.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfb bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 30 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is c94e9c3047e1b2a489be14d1ba0590a0.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfb bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 31 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is d5ad152d6475b521b1121c26203c3aba.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfb bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 32 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is e5858ef1d3c13fc1fc9400768c00693e.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfb bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 33 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is 9d7848e59564865ba9e1db1a1ab69e4a.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfb bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 34 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is a94ab5626535dc936891c95fed20b3b7.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfb bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 35 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is ac83d57e598fbc274b19e74ef133ff86.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfb bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 36 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is 50ddb48d0e6a6e5f378ad6a1d74a15b3.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfb bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 37 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is be22815b863f6733f1fc9d53b6cb7cff.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfb bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 38 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is c20db30cca537e96c0e3f09148ec293a.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfb bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 39 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is a304ed4b4186217da28db69daf1b81d5.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xd9 bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 40 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is e536a1a4d5753f209168e52f95ca8b59.\n'
# [DEBUG] Received 0x16d bytes:
#     b'Thank you for using our service !\n'
# ...
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfb bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 95 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is 0a4959886c793dbff240291397798c04.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfb bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 96 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is 511af7849b0c93c116d4f75b30eb9dba.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xd9 bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 97 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is a2baec507ffc01c6793b4bde352a5545.\n'
# [DEBUG] Received 0x16d bytes:
#     b'Thank you for using our service !\n'
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfb bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 98 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is 89a99b2c606d61164a9fdb15fa3b0288.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0x5e bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 99 times.\n'
# [DEBUG] Received 0x1e8 bytes:
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is beea8b0eee1e1799ca5930b84c79dda4.\n'
#     b'Thank you for using our service !\n'
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfc bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 100 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is 797c68d2079cfab9a9a833211a9b4e71.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfc bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 101 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is 231601883af636a207e5c98aea557e5a.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfc bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 102 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is 2285441f3718fc1282de5d0f2253a0f0.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfc bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 103 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is d891daf3d2933c3af1335034e3da8598.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfc bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 104 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is 07c5bc8302f03d9afb332147ca937de5.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x14b bytes:
#     b'Your new token is :  \n'
#     b'Menu:\n'
#     b'1. Logs\n'
#     b'2. Get Flag\n'
#     b'3. Exit\n'
#     b'Enter your choice: '
# [DEBUG] Sent 0x2 bytes:
#     b'1\n'
# [DEBUG] Sent 0x121 bytes:
#     b'\n'
# [DEBUG] Received 0x28 bytes:
#     b'Would you kindly input your session id: '
# [DEBUG] Received 0xfc bytes:
#     b'Welcome to your inbox !\n'
#     b'---> You have 1 message <---\n'
#     b'---> You have encrypted a text 105 times.\n'
#     b'---> Unfortunatly you are still single.\n'
#     b'---> The current key that was used to encrypt is 06db1fb39b41b24a9faed2e47a912136.\n'
#     b'Thank you for using our service !\n'
# [DEBUG] Received 0x4cd bytes:
#     b'Traceback (most recent call last):\n'
#     b'  File "/usr/src/app/main.py", line 84, in <module>\n'
#     b'    main()\n'
#     b'  File "/usr/src/app/main.py", line 57, in main\n'
#     b'    token = cipher.encrypt()\n'
#     b'            ^^^^^^^^^^^^^^^^\n'
#     b'  File "/usr/src/app/main.py", line 33, in encrypt\n'
#     b'    cipher = AES.new(key, AES.MODE_CBC, iv=self.iv)\n'
#     b'             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n'
#     b'  File "/usr/local/lib/python3.11/site-packages/Crypto/Cipher/AES.py", line 228, in new\n'
#     b'    return _create_cipher(sys.modules[__name__], key, mode, *args, **kwargs)\n'
#     b'           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n'
#     b'  File "/usr/local/lib/python3.11/site-packages/Crypto/Cipher/__init__.py", line 79, in _create_cipher\n'
#     b'    return modes[mode](factory, **kwargs)\n'
#     b'           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n'
#     b'  File "/usr/local/lib/python3.11/site-packages/Crypto/Cipher/_mode_cbc.py", line 274, in _create_cbc_cipher\n'
#     b'    cipher_state = factory._create_base_cipher(kwargs)\n'
#     b'                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n'
#     b'  File "/usr/local/lib/python3.11/site-packages/Crypto/Cipher/AES.py", line 90, in _create_base_cipher\n'
#     b'    raise ValueError("Incorrect AES key length (%d bytes)" % len(key))\n'
#     b'ValueError: Incorrect AES key length (15 bytes)\n'
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# /tmp/ipykernel_40267/323387271.py in <module>
#      11     iv[-1] ^= 2 ^ (48 + 1)
#      12     iv[-2] ^= ord('C') ^ 0x8c
# ---> 13     p.recvuntil(b'Your new token is :  ')
#      14     enc = bytearray.fromhex(p.recvline(keepends=False).decode())
#      15     enc[79 - 16] ^= 1
#
# ~/.local/lib/python3.10/site-packages/pwnlib/tubes/tube.py in recvuntil(self, delims, drop, timeout)
#     339             while self.countdown_active():
#     340                 try:
# --> 341                     res = self.recv(timeout=self.timeout)
#     342                 except Exception:
#     343                     self.unrecv(b''.join(data) + top)
#
# ~/.local/lib/python3.10/site-packages/pwnlib/tubes/tube.py in recv(self, numb, timeout)
#     104         """
#     105         numb = self.buffer.get_fill_size(numb)
# --> 106         return self._recv(numb, timeout) or b''
#     107
#     108     def unrecv(self, data):
#
# ~/.local/lib/python3.10/site-packages/pwnlib/tubes/tube.py in _recv(self, numb, timeout)
#     174         # No buffered data, could not put anything in the buffer
#     175         # before timeout.
# --> 176         if not self.buffer and not self._fillbuffer(timeout):
#     177             return b''
#     178
#
# ~/.local/lib/python3.10/site-packages/pwnlib/tubes/tube.py in _fillbuffer(self, timeout)
#     153
#     154         with self.local(timeout):
# --> 155             data = self.recv_raw(self.buffer.get_fill_size())
#     156
#     157         if data and self.isEnabledFor(logging.DEBUG):
#
# ~/.local/lib/python3.10/site-packages/pwnlib/tubes/sock.py in recv_raw(self, numb, *a)
#      54         if not data:
#      55             self.shutdown("recv")
# ---> 56             raise EOFError
#      57
#      58         return data
#
# EOFError:

# %%
from pwn import *
from randcrack import RandCrack
from Crypto.Util.number import long_to_bytes

rc = RandCrack()
p = remote('20.80.240.190', 4447, level = 'debug')
username = "0" * 25 + b'\xe1\x94\x89'.decode()
p.sendlinethen(b'IV used during this session:  ', username.encode())
iv = bytearray.fromhex(p.recvline(keepends=False).decode())
for _ in range(624 // 4):
    iv[-1] ^= 2 ^ (48 + 1)
    iv[-2] ^= ord('C') ^ 0x8c
    p.recvuntil(b'Your new token is :  ')
    enc = bytearray.fromhex(p.recvline(keepends=False).decode())
    enc[79 - 16] ^= 1
    p.sendline(b'1')
    p.sendlinethen(b'encrypt is ', (iv + enc).hex().encode())
    randbits128 = bytes.fromhex(p.recvline()[:-2].decode())
    big = randbits128[::-1]
    for i in range(4):
        randbits32 = int.from_bytes(big[i * 4: i * 4 + 4], byteorder='little')
        rc.submit(randbits32)
rc.predict_getrandbits(128)
p.sendline(b'2')
p.sendline(long_to_bytes(rc.predict_getrandbits(128)).hex().encode())
p.interactive()
